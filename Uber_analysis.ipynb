# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Uber Supply Demand Analysis
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# 📌 Purpose:
# This dataset records Uber ride requests over a few days in July 2016. It's designed to analyze ride demand, supply issues, driver availability, and request patterns over time.
#
#
# 📂 Columns Description:
# Column Name	Description
# Request id	Unique identifier for each ride request.
#
# Pickup point	Location where the rider wants pickup — either from City or Airport.
#
# Driver id	Unique ID of the driver who accepted the request. Missing if no driver was assigned.
#
# Status	Final outcome of the ride request — values include: Trip Completed, Cancelled, No Cars Available.
#
# Request timestamp	Time at which the request was made. Format is inconsistent (needs parsing).
#
# Drop timestamp	Time at which the trip ended. Missing for cancelled/unfulfilled rides.
#
# hour (derived)	Hour of day (0–23) extracted from the request timestamp to support time-based analysis.
#
# 📊 Key Characteristics:
#
# Total records: 6745
#
# High cancellation and unavailability rates, especially during peak hours.
#
# Useful for identifying:
#
# Peak request times
#
# Driver supply-demand gaps
#
# Location-based issues (Airport vs City)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/dkarthik777/DATA-ANALYSIS

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Uber Ride Supply-Demand Gap Analysis**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze Uber ride request data and identify the root causes of service failures, particularly:
#
# When and where ride requests are not being fulfilled.
#
# Why supply-demand gaps occur.
#
# How Uber can improve ride availability and reduce cancellations.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Uber Request Data.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (6745, 6)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.isnull().sum()
# Out:
# Request id              0
# Pickup point            0
# Driver id            2650
# Status                  0
# Request timestamp       0
# Drop timestamp       3914
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Visualizing the missing values
df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Our Dataset consists of 6745 rows and 6 coloumns. The coloumns are mainly Requstid, pickup point, driver id,status, drop and request timestamp
# there are missing are in driver id and drop timestamp. we dont want to remove them because driver id and drop time are negligible here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         Request id    Driver id
# count  6745.000000  4095.000000
# mean   3384.644922   149.501343
# std    1955.099667    86.051994
# min       1.000000     1.000000
# 25%    1691.000000    75.000000
# 50%    3387.000000   149.000000
# 75%    5080.000000   224.000000
# max    6766.000000   300.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The above is the small description of request id and driver id.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# Request id           6745
# Pickup point            2
# Driver id             300
# Status                  3
# Request timestamp    5618
# Drop timestamp       2598
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
sns.countplot(data=df, x='Status', palette='pastel')
plt.title('Univariate: Ride Request Status Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.boxplot(data=df, x='Driver id', palette='pastel')
plt.title('Univariate: Driver id')
plt.xlabel('Driver id')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.histplot(data=df, x='Pickup point', palette='pastel')
plt.title('Univariate')
plt.xlabel('Pickup Point')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pickup point', hue='Status', palette='Set2')
plt.title('Bivariate: Status by Pickup Point')
plt.xlabel('Pickup Point')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pickup point', hue='Status', palette='Set2')
plt.title('Bivariate: Status by Pickup Point')
plt.xlabel('Pickup Point')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Multivariate: Requests by Hour and Status
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], dayfirst=True, errors='coerce')
df['hour'] = df['Request timestamp'].dt.hour

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='hour', hue='Status', palette='muted')
plt.title('Multivariate: Requests by Hour and Status')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Requests')
plt.legend(title='Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corr_matrix = df.corr(numeric_only=True)

print(corr_matrix)
plt.figure(figsize=(8, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar=True)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
#             Request id  Driver id      hour
# Request id    1.000000  -0.013602  0.444925
# Driver id    -0.013602   1.000000  0.015753
# hour          0.444925   0.015753  1.000000

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Select numeric columns only (e.g., hour, trip duration if present)
numeric_df = df.select_dtypes(include=['number'])

# Plot pairplot
sns.pairplot(numeric_df, diag_kind='kde', corner=True)
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Dynamic Driver Scheduling
# Incentivize drivers to log in during peak hours (especially early morning and evening).
#
#     Use historical demand data to predict and auto-alert idle drivers in advance.
# 2. Improve User Communication
# If cars are not available, offer estimated wait times instead of an immediate "No Cars Available" message.
#
#    Promote ride scheduling features for Airport trips ahead of time.
# 3. Real-time Monitoring Dashboard
# Deploy a dashboard to track:
#
#   Live supply-demand heatmaps
#
#   Hourly and location-based cancellation rates
#
#   Driver login/logout patterns

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Based on the analysis of Uber ride request data:
#
# High Demand Periods (especially 5 AM–9 AM and 5 PM–9 PM) experience a significant supply-demand gap, where a large number of ride requests are either cancelled or marked as No Cars Available.
#
# Airport pickup location suffers more from unfulfilled requests compared to the City, indicating poor supply during high outbound/inbound traveler times.
#
# A large percentage of requests have no drivers assigned, especially during peak hours, revealing a driver shortage problem in certain time windows.
#
# Most Trip Completed statuses are skewed toward mid-day hours when demand and supply are relatively balanced.
